# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # data frame- file handling

# %%
df = pd.read_csv('supermarkets.csv')
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ###### tabular format me laya

# %%
df = pd.read_csv('supermarkets.csv', index_col = 0) # i am making 0th col as index

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1 =pd.read_csv('supermarkets-commas.txt')
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#we are just reading and showing

# %%
df2 = pd.read_csv('supermarkets-semi-colons.txt')
df2  #ye by default comma ke liye karta hai isilye pura kachra kar diya isne colon ko
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
#read csv bohot sari files ko handle karta hai 
#chahe file ka extension csv ho ki na ho 
#fark parta hai andar rakhe data se 
#mujhe jis form me data chaiye us form me hona chaiye bas

# %%
df2 = pd.read_csv('supermarkets-semi-colons.txt',sep = ';')
df2  #ye by default comma ke liye karta hai isilye pura kachra kar diya isne colon ko
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#Easy hai na

# %%
df3 = pd.read_csv('supermarkets-commas-nohead.txt')
df3  #mujhe apna data as heading nhi chaiye me dungi data
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df3 = pd.read_csv('supermarkets-commas-nohead.txt',names = ['ID','Address','City','State','Country','Name','Employees'])
df3  #mujhe apna data as heading nhi chaiye me dungi data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pd.read_json('supermarkets.json')
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_excel('supermarkets.xlsx')
df5
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
#all these are data frames 
# insabhi read file ka counter version bhi hota hai  #to save
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.to_csv('mydata.csv')

# %%
df.to_csv('mydata1.csv',index = False,)

# %%
df.to_csv('mydata2.csv',index = False,header = False,sep = '+',)

# %%
#csv ko to bas comma

# %%
df.to_csv('mydata3.csv',index = False,header = False,sep = '|',)

# %%
#data dalna hai mujhe 
df.loc[6]
# Out:
# Address      551 Alvarado St
# City           San Francisco
# State               CA 94114
# Country                  USA
# Name              Richvalley
# Employees                 20
# Name: 6, dtype: object

# %%
#ye data mujhe is my data file me dalna hai 
dd =pd.DataFrame(df.loc[6]).T
dd
# Out:
#            Address           City     State Country        Name Employees
# 6  551 Alvarado St  San Francisco  CA 94114     USA  Richvalley        20

# %%
dd.to_csv('mydata2.csv',index = False, header = False , mode = 'a') ## append kiya last me

# %% [markdown]
# ## <b>Logical indexing </b>

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#mujhe kisine pucha ki un super markets ka nam do jahan no of employees 10 se jyada hai

# %%
#ye fundamental concept hai

# %%
df['Employees']>10
# Out:
# ID
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# Name: Employees, dtype: bool

# %%
df['Name'][True,False] #ise samjh nhi aya
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-a24bcacc0094> in <module>
# ----> 1 df['Name'][True,False]
#
# ~\ML\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\ML\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# ...

# %%
df['Name'][True,False,True,False,False,True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-d7a23b3c1665> in <module>
# ----> 1 df['Name'][True,False,True,False,False,True]
#
# ~\ML\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\ML\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
df['Name']([True,False,True,False,False,True])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-dcffed1419d4> in <module>
# ----> 1 df['Name']([True,False,True,False,False,True])
#
# TypeError: 'Series' object is not callable

# %%
df['Name'][pd.Series([True, False,True,True,False,False],index = [1,2,3,4,5,6])]
# Out:
# ID
# 1        Madeira
# 3    Super River
# 4     Ben's Shop
# Name: Name, dtype: object

# %%
df['Name'][df['Employees']>10]
# Out:
# ID
# 2    Bready Shop
# 3    Super River
# 5        Sanchez
# 6     Richvalley
# Name: Name, dtype: object

# %%
df[df['Employees']>10]   #andar se execute hua
# Out:
#             Address           City             State Country         Name  \
# ID
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 2          15
# 3          25
# 5          12
# 6          20

# %%
#greater >10 or <20

# %%
df[(df['Employees']>10)&(df['Employees']<=20)]  #binary operator
# Out:
#             Address           City       State Country         Name  Employees
# ID
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop         15
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez         12

# %%
df['Employees']>10
# Out:
# ID
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# Name: Employees, dtype: bool

# %%
df['Employees']<=10
# Out:
# ID
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# Name: Employees, dtype: bool

# %%
[(df['Employees']>10)&(df['Employees']<=10)]
# Out:
# [ID
#  1    False
#  2    False
#  3    False
#  4    False
#  5    False
#  6    False
#  Name: Employees, dtype: bool]

# %%
df[['Name','Employees']][(df['Employees']>10)&(df['Employees']<=20)]
# Out:
#            Name  Employees
# ID
# 2   Bready Shop         15
# 5       Sanchez         12
# 6    Richvalley         20

# %% [markdown]
# ## Stastical Functions

# %%
df.describe()
# Out:
#        Employees
# count   6.000000
# mean   15.000000
# std     6.449806
# min     8.000000
# 25%    10.500000
# 50%    13.500000
# 75%    18.750000
# max    25.000000

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.drop('Employees',axis = 1)  #just returning original data is same
# Out:
#             Address           City             State Country         Name
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley

# %%
#df.drop('Employees',axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 1 to 6
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Address    6 non-null      object
#  1   City       6 non-null      object
#  2   State      6 non-null      object
#  3   Country    6 non-null      object
#  4   Name       6 non-null      object
#  5   Employees  6 non-null      int64
# dtypes: int64(1), object(5)
# memory usage: 496.0+ bytes

# %%
df.drop(['Employees'],axis = 1).describe()
# Out:
#             Address           City     State Country     Name
# count             6              6         6       6        6
# unique            6              1         4       1        6
# top     332 Hill St  San Francisco  CA 94114     USA  Sanchez
# freq              1              6         3       6        1

# %%
df.drop(['Employees'],axis = 1)
# Out:
#             Address           City             State Country         Name
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley

# %%
#top give us frequency 
#unique the no. of unique data 
#count give us the no. of counts 
#frq the no of times it occured

# %%
df.describe(include='all')
# Out:
#             Address           City     State Country     Name  Employees
# count             6              6         6       6        6   6.000000
# unique            6              1         4       1        6        NaN
# top     332 Hill St  San Francisco  CA 94114     USA  Sanchez        NaN
# freq              1              6         3       6        1        NaN
# mean            NaN            NaN       NaN     NaN      NaN  15.000000
# std             NaN            NaN       NaN     NaN      NaN   6.449806
# min             NaN            NaN       NaN     NaN      NaN   8.000000
# 25%             NaN            NaN       NaN     NaN      NaN  10.500000
# 50%             NaN            NaN       NaN     NaN      NaN  13.500000
# 75%             NaN            NaN       NaN     NaN      NaN  18.750000
# max             NaN            NaN       NaN     NaN      NaN  25.000000

# %%
df.mean()
# Out:
# Employees    15.0
# dtype: float64

# %%
df.min()
# Out:
# Address      1056 Sanchez St
# City           San Francisco
# State               CA 94114
# Country                  USA
# Name              Ben's Shop
# Employees                  8
# dtype: object

# %%
df.sum()
# Out:
# Address      3666 21st St735 Dolores St332 Hill St3995 23rd...
# City         San FranciscoSan FranciscoSan FranciscoSan Fra...
# State        CA 94114CA 94119California 94114CA 94114Califo...
# Country                                     USAUSAUSAUSAUSAUSA
# Name         MadeiraBready ShopSuper RiverBen's ShopSanchez...
# Employees                                                   90
# dtype: object

# %%
df.median()
# Out:
# Employees    13.5
# dtype: float64

# %%
df.quantile(0.25)
# Out:
# Employees    10.5
# Name: 0.25, dtype: float64

# %%
data = pd.read_csv('Data.csv')

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.cov(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-cf1b88674e57> in <module>
# ----> 1 df.cov(data)
#
# ~\ML\lib\site-packages\pandas\core\frame.py in cov(self, min_periods)
#    7599
#    7600         if notna(mat).all():
# -> 7601             if min_periods is not None and min_periods > len(mat):
#    7602                 baseCov = np.empty((mat.shape[1], mat.shape[1]))
#    7603                 baseCov.fill(np.nan)
#
# ~\ML\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#     850             # straight boolean comparisons we want to allow all columns
#     851             # (regardless of dtype to pass thru) See #4537 for discussion.
# --> 852             new_data = dispatch_to_series(self, other, op)
#     853             return self._construct_result(new_data)
#     854
#
# ...

# %%
df['Employees'].cov(data['Age'])
# Out:
# 14.0

# %%
#cov do data ke bich me hota hai

# %%
#correlation 
data.corr()  #numerical correlations
# Out:
#              Age    Salary
# Age     1.000000  0.982495
# Salary  0.982495  1.000000

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
pd.crosstab(index = data['Country'],columns = data['Purchased'])
# Out:
# Purchased  No  Yes
# Country
# France      1    3
# Germany     2    1
# Spain       2    1

# %%
pd.pivot_table(data,index = 'Country',columns ='Purchased',values = 'Salary',aggfunc = np.mean)
# Out:
# Purchased       No      Yes
# Country
# France     72000.0  68000.0
# Germany    68500.0      NaN
# Spain      56500.0  48000.0

# %% [markdown]
# ### string/Text_Based_Functions

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#agar  string based operations karne ho to kya kar sakte hai 
##sare string functions works on series only 
ad = df['Address']
ad
# Out:
# ID
# 1       3666 21st St
# 2     735 Dolores St
# 3        332 Hill St
# 4       3995 23rd St
# 5    1056 Sanchez St
# 6    551 Alvarado St
# Name: Address, dtype: object

# %%
ad.str.split()
# Out:
# ID
# 1       [3666, 21st, St]
# 2     [735, Dolores, St]
# 3        [332, Hill, St]
# 4       [3995, 23rd, St]
# 5    [1056, Sanchez, St]
# 6    [551, Alvarado, St]
# Name: Address, dtype: object

# %%
ad.str.split([0])
# Out:
# ID
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# Name: Address, dtype: float64

# %%
ad.str.split().get_value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-cae6bc5dd50b> in <module>
# ----> 1 ad.str.split().get_value()
#
# ~\ML\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'get_value'

# %%
ad.str.lower()
# Out:
# ID
# 1       3666 21st st
# 2     735 dolores st
# 3        332 hill st
# 4       3995 23rd st
# 5    1056 sanchez st
# 6    551 alvarado st
# Name: Address, dtype: object

# %%
ad.str.count('t')
# Out:
# ID
# 1    2
# 2    1
# 3    1
# 4    1
# 5    1
# 6    1
# Name: Address, dtype: int64

# %%
ad.str.split().str.get(0)  #list me first element de raha hai
# Out:
# ID
# 1    3666
# 2     735
# 3     332
# 4    3995
# 5    1056
# 6     551
# Name: Address, dtype: object

# %%
ad.str.get(-1)
# Out:
# ID
# 1    t
# 2    t
# 3    t
# 4    t
# 5    t
# 6    t
# Name: Address, dtype: object

# %%
ad.str.len()
# Out:
# ID
# 1    12
# 2    14
# 3    11
# 4    12
# 5    15
# 6    15
# Name: Address, dtype: int64

# %%
ad.str.get_dummies() #converts data into columns  jese ki column ko address bana diya or or wahan unke badle 1 laga diya
# Out:
#     1056 Sanchez St  332 Hill St  3666 21st St  3995 23rd St  551 Alvarado St  \
# ID
# 1                 0            0             1             0                0
# 2                 0            0             0             0                0
# 3                 0            1             0             0                0
# 4                 0            0             0             1                0
# 5                 1            0             0             0                0
# 6                 0            0             0             0                1
#
#     735 Dolores St
# ID
# 1                0
# 2                1
# 3                0
# 4                0
# 5                0
# 6                0

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data['Country'].str.get_dummies()
# Out:
#    France  Germany  Spain
# 0       1        0      0
# 1       0        0      1
# 2       0        1      0
# 3       0        0      1
# 4       0        1      0
# 5       1        0      0
# 6       0        0      1
# 7       1        0      0
# 8       0        1      0
# 9       1        0      0

# %%
pd.get_dummies(data['Country'])
# Out:
#    France  Germany  Spain
# 0       1        0      0
# 1       0        0      1
# 2       0        1      0
# 3       0        0      1
# 4       0        1      0
# 5       1        0      0
# 6       0        0      1
# 7       1        0      0
# 8       0        1      0
# 9       1        0      0

# %%
#all data needs to be in numerical form for machine learning

# %%
#we use this when we have catrgorical info

# %%
#weightage wise data nhi dal sakte categorical me-- isiliye - we use dummies

# %%
ad.str.cat(sep = '$$')
# Out:
# '3666 21st St$$735 Dolores St$$332 Hill St$$3995 23rd St$$1056 Sanchez St$$551 Alvarado St'

# %% [markdown]
# ### Iteration and Function Applications

# %% [markdown]
# wo split wala na hum function application ke through bhi kar sakte hai

# %%
ad.apply(lambda x:x.split()[0])
# Out:
# ID
# 1    3666
# 2     735
# 3     332
# 4    3995
# 5    1056
# 6     551
# Name: Address, dtype: object

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df['Full_address'] = df[['Address','City','Country']].apply(lambda x:'{} in {},{}'.format(x['Address'].split()[0],x['City'],x['Country']),axis = 1)
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees               Full_address
# ID
# 1           8  3666 in San Francisco,USA
# 2          15   735 in San Francisco,USA
# 3          25   332 in San Francisco,USA
# 4          10  3995 in San Francisco,USA
# 5          12  1056 in San Francisco,USA
# 6          20   551 in San Francisco,USA

# %% [markdown]
# ### iteration
# 1.iteritems
# 2.iterrows
# 3.itertuples

# %%
for i in df:
    print(i)
# Out:
# Address
# City
# State
# Country
# Name
# Employees
# Full_address

# %%
for i in df:
    print(df[i])
# Out:
# ID
# 1       3666 21st St
# 2     735 Dolores St
# 3        332 Hill St
# 4       3995 23rd St
# 5    1056 Sanchez St
# 6    551 Alvarado St
# Name: Address, dtype: object
# ID
# 1    San Francisco
# 2    San Francisco
# 3    San Francisco
# 4    San Francisco
# 5    San Francisco
# 6    San Francisco
# Name: City, dtype: object
# ID
# 1            CA 94114
# 2            CA 94119
# 3    California 94114
# 4            CA 94114
# 5          California
# 6            CA 94114
# Name: State, dtype: object
# ID
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# 6    USA
# Name: Country, dtype: object
# ID
# 1        Madeira
# 2    Bready Shop
# 3    Super River
# 4     Ben's Shop
# 5        Sanchez
# 6     Richvalley
# Name: Name, dtype: object
# ID
# 1     8
# 2    15
# 3    25
# 4    10
# 5    12
# 6    20
# Name: Employees, dtype: int64
# ID
# 1    3666 in San Francisco,USA
# 2     735 in San Francisco,USA
# 3     332 in San Francisco,USA
# 4    3995 in San Francisco,USA
# ...

# %%
for i in range(1,len(df)+1):
    print(df.loc[i])
# Out:
# Address                      3666 21st St
# City                        San Francisco
# State                            CA 94114
# Country                               USA
# Name                              Madeira
# Employees                               8
# Full_address    3666 in San Francisco,USA
# Name: 1, dtype: object
# Address                   735 Dolores St
# City                       San Francisco
# State                           CA 94119
# Country                              USA
# Name                         Bready Shop
# Employees                             15
# Full_address    735 in San Francisco,USA
# Name: 2, dtype: object
# Address                      332 Hill St
# City                       San Francisco
# State                   California 94114
# Country                              USA
# Name                         Super River
# Employees                             25
# Full_address    332 in San Francisco,USA
# Name: 3, dtype: object
# ...

# %%
k = []
for i in range(1,len(df)+1):
    k.append('{} in {},{}'.format(df['Address'][i].split()[0],df['City'][i],df['Country'][i]))

# %%
k
# Out:
# ['3666 in San Francisco,USA',
#  '735 in San Francisco,USA',
#  '332 in San Francisco,USA',
#  '3995 in San Francisco,USA',
#  '1056 in San Francisco,USA',
#  '551 in San Francisco,USA']

# %%
print(k)
# Out:
# ['3666 in San Francisco,USA', '735 in San Francisco,USA', '332 in San Francisco,USA', '3995 in San Francisco,USA', '1056 in San Francisco,USA', '551 in San Francisco,USA']

# %%
#bar bar ek hi dataframe load kar rahe hai

# %%
#isi chiz ko with generator

# %%
for i,v in df.iteritems():
    print(i)
    print(v)
    break
    #working as generator
# Out:
# Address
# ID
# 1       3666 21st St
# 2     735 Dolores St
# 3        332 Hill St
# 4       3995 23rd St
# 5    1056 Sanchez St
# 6    551 Alvarado St
# Name: Address, dtype: object

# %%
for i,v in df.iterrows():
    print(i)
    print(v)
    break
# Out:
# 1
# Address                      3666 21st St
# City                        San Francisco
# State                            CA 94114
# Country                               USA
# Name                              Madeira
# Employees                               8
# Full_address    3666 in San Francisco,USA
# Name: 1, dtype: object

# %%
for i in df.itertuples():
    print(i)
    #it is pandas tuple
# Out:
# Pandas(Index=1, Address='3666 21st St', City='San Francisco', State='CA 94114', Country='USA', Name='Madeira', Employees=8, Full_address='3666 in San Francisco,USA')
# Pandas(Index=2, Address='735 Dolores St', City='San Francisco', State='CA 94119', Country='USA', Name='Bready Shop', Employees=15, Full_address='735 in San Francisco,USA')
# Pandas(Index=3, Address='332 Hill St', City='San Francisco', State='California 94114', Country='USA', Name='Super River', Employees=25, Full_address='332 in San Francisco,USA')
# Pandas(Index=4, Address='3995 23rd St', City='San Francisco', State='CA 94114', Country='USA', Name="Ben's Shop", Employees=10, Full_address='3995 in San Francisco,USA')
# Pandas(Index=5, Address='1056 Sanchez St', City='San Francisco', State='California', Country='USA', Name='Sanchez', Employees=12, Full_address='1056 in San Francisco,USA')
# ...

# %%
for i in df.itertuples():
    print(i)
    print(i[1])
    #it is pandas tuple
# Out:
# Pandas(Index=1, Address='3666 21st St', City='San Francisco', State='CA 94114', Country='USA', Name='Madeira', Employees=8, Full_address='3666 in San Francisco,USA')
# 3666 21st St
# Pandas(Index=2, Address='735 Dolores St', City='San Francisco', State='CA 94119', Country='USA', Name='Bready Shop', Employees=15, Full_address='735 in San Francisco,USA')
# 735 Dolores St
# Pandas(Index=3, Address='332 Hill St', City='San Francisco', State='California 94114', Country='USA', Name='Super River', Employees=25, Full_address='332 in San Francisco,USA')
# 332 Hill St
# Pandas(Index=4, Address='3995 23rd St', City='San Francisco', State='CA 94114', Country='USA', Name="Ben's Shop", Employees=10, Full_address='3995 in San Francisco,USA')
# 3995 23rd St
# Pandas(Index=5, Address='1056 Sanchez St', City='San Francisco', State='California', Country='USA', Name='Sanchez', Employees=12, Full_address='1056 in San Francisco,USA')
# 1056 Sanchez St
# ...

# %%
#hum pandas sikh rahe hai

# %%
#sorting /Reindexing

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees               Full_address
# ID
# 1           8  3666 in San Francisco,USA
# 2          15   735 in San Francisco,USA
# 3          25   332 in San Francisco,USA
# 4          10  3995 in San Francisco,USA
# 5          12  1056 in San Francisco,USA
# 6          20   551 in San Francisco,USA

# %%
df.sort_index()
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees               Full_address
# ID
# 1           8  3666 in San Francisco,USA
# 2          15   735 in San Francisco,USA
# 3          25   332 in San Francisco,USA
# 4          10  3995 in San Francisco,USA
# 5          12  1056 in San Francisco,USA
# 6          20   551 in San Francisco,USA

# %%
df.sort_index(ascending = False)
# Out:
#             Address           City             State Country         Name  \
# ID
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
#
#     Employees               Full_address
# ID
# 6          20   551 in San Francisco,USA
# 5          12  1056 in San Francisco,USA
# 4          10  3995 in San Francisco,USA
# 3          25   332 in San Francisco,USA
# 2          15   735 in San Francisco,USA
# 1           8  3666 in San Francisco,USA

# %%
df.sort_index(ascending = False,axis = 1)
# Out:
#                State         Name               Full_address  Employees  \
# ID
# 1           CA 94114      Madeira  3666 in San Francisco,USA          8
# 2           CA 94119  Bready Shop   735 in San Francisco,USA         15
# 3   California 94114  Super River   332 in San Francisco,USA         25
# 4           CA 94114   Ben's Shop  3995 in San Francisco,USA         10
# 5         California      Sanchez  1056 in San Francisco,USA         12
# 6           CA 94114   Richvalley   551 in San Francisco,USA         20
#
#    Country           City          Address
# ID
# 1      USA  San Francisco     3666 21st St
# 2      USA  San Francisco   735 Dolores St
# 3      USA  San Francisco      332 Hill St
# 4      USA  San Francisco     3995 23rd St
# 5      USA  San Francisco  1056 Sanchez St
# 6      USA  San Francisco  551 Alvarado St

# %%
df.sort_values('Employees')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
#
#     Employees               Full_address
# ID
# 1           8  3666 in San Francisco,USA
# 4          10  3995 in San Francisco,USA
# 5          12  1056 in San Francisco,USA
# 2          15   735 in San Francisco,USA
# 6          20   551 in San Francisco,USA
# 3          25   332 in San Francisco,USA

# %%
df.sort_values('Employees',ascending = False)
# Out:
#             Address           City             State Country         Name  \
# ID
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
#
#     Employees               Full_address
# ID
# 3          25   332 in San Francisco,USA
# 6          20   551 in San Francisco,USA
# 2          15   735 in San Francisco,USA
# 5          12  1056 in San Francisco,USA
# 4          10  3995 in San Francisco,USA
# 1           8  3666 in San Francisco,USA

# %%
df.rename(columns = {'Full_address':'Full Address'})
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees               Full Address
# ID
# 1           8  3666 in San Francisco,USA
# 2          15   735 in San Francisco,USA
# 3          25   332 in San Francisco,USA
# 4          10  3995 in San Francisco,USA
# 5          12  1056 in San Francisco,USA
# 6          20   551 in San Francisco,USA

# %%
df.rename(columns = {'Full_address':'Full Address'},inplace = True)

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees               Full Address
# ID
# 1           8  3666 in San Francisco,USA
# 2          15   735 in San Francisco,USA
# 3          25   332 in San Francisco,USA
# 4          10  3995 in San Francisco,USA
# 5          12  1056 in San Francisco,USA
# 6          20   551 in San Francisco,USA
