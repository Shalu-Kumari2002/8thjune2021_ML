# %% [markdown]
# # MATPLOTLIB

# %%
#libraries used for data visualisation

# %%
import matplotlib.pyplot  as plt

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**3

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)

# %% [markdown]
# ## Graphs
# 1. plot - line plotting
# 2.bar - bar graph of data
#     -horizontal--barh
# 3.hist  histogram of data(freq of data)
# 4. scatter - point plot of relationship between two features
# 5. boxplot - boxplot (median , 0.25,
#                      /0.75 quantile, outliers )
# 6. box - same as boxplot
# 7.stem - point  plot with bars
# 8.violinplot - median, density of data in the shape of violin

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 11 artists>

# %%
plt.barh(x,y)  #horizontal
# Out:
# <BarContainer object of 11 artists>

# %%
plt.bar(y,x)
# Out:
# <BarContainer object of 11 artists>

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 11 artists>

# %%
plt.hist(y)  #it divided in bins
# Out:
# (array([5., 1., 1., 1., 0., 1., 0., 1., 0., 1.]),
#  array([  0. ,  12.5,  25. ,  37.5,  50. ,  62.5,  75. ,  87.5, 100. ,
#         112.5, 125. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(y,bins = 4)
# Out:
# (array([7., 1., 2., 1.]),
#  array([  0.  ,  31.25,  62.5 ,  93.75, 125.  ]),
#  <a list of 4 Patch objects>)

# %%
len(y)
# Out:
# 11

# %%
plt.hist(y,bins = 4) 
# ye range ki value dikha raha hai #bins me equal distance ke blocks bana dete hai
# Out:
# (array([7., 1., 2., 1.]),
#  array([  0.  ,  31.25,  62.5 ,  93.75, 125.  ]),
#  <a list of 4 Patch objects>)

# %%
plt.scatter(x,y)

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f605e13250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f605e13910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f605e02eb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f605e13fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f605e1c310>],
#  'means': []}

# %%
##whiskers - bich ka line median hai 
#or wo box

# %% [markdown]
# <img src = 'https://miro.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png'>

# %%
plt.box(y)  #category ke time ise use karenge
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\ML\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\ML\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\ML\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

plt.stem(y)
plt.show()  #after using this we we dont see the values

# %%
p = plt.boxplot(y)

# %%
plt.violinplot(y)  #its showing max values are in the range 0 t 10
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f6061d4700>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f6061d4580>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f6061d45e0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f6061d4b50>}

# %%
a = np.random.randint(1,100,(30))
b = np.random.randint(1,100,(30)) * np.random.rand(1)

# %%
plt.plot(a)

# %%
plt.plot(b)

# %%
plt.figure(figsize = (20,8))
plt.plot(a)

# %%
plt.figure(figsize = (10,6))
plt.plot(a)

# %%
plt.figure(figsize = (10,6))
plt.plot(a)
plt.grid()

# %%
plt.figure(figsize = (10,6))
plt.plot(a, color = 'r', ls = '-.', marker = '*',markersize = 10,)
plt.title('My Graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(a, color = 'r', ls = '-.', marker = '*',markersize = 10,markeredgecolor = 'g',markerfacecolor = 'deeppink')
plt.title('My Graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(a, color = 'r', ls = '-.', marker = '*',markersize = 10,markeredgecolor = 'g',markerfacecolor = 'deeppink')
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,2))
plt.ylabel('y-axis')
plt.yticks(range(0,100,5))

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(a, color = 'r', ls = '-.', marker = '*',markersize = 10,markeredgecolor = 'g',markerfacecolor = 'deeppink')
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,2),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,100,5))

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(a, color = 'r', ls = '-.', marker = '*',markersize = 10,markeredgecolor = 'g',markerfacecolor = 'deeppink')
plt.plot(b, color = 'm', ls = ':', marker = 'o',markersize = 10,markeredgecolor = 'blue',markerfacecolor = 'red')
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,2),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,100,5))
plt.legend(['Data A','DataB'])

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.boxplot(a,)
plt.boxplot(b,)
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,1),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,10,1))
plt.legend(['Data A','Data B'])

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.scatter(a,list(range(0,30,1)))
plt.scatter(b,list(range(0,30,1)))
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,1),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,10,1))
plt.legend(['Data A','Data B'])

plt.show()

# %%
len(a)
# Out:
# 30

# %%
plt.figure(figsize = (10,6))
plt.bar(a,list(range(0,30,1)))
plt.bar(b,list(range(0,30,1)))
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,1),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,10,1))
plt.legend(['Data A','Data B'])

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(a,list(range(0,30,1)))
plt.plot(b,list(range(0,30,1)))
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,1),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,10,1))
plt.legend(['Data A','Data B'])

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.hist(a,list(range(0,30,1)))
plt.hist(b,list(range(0,30,1)))
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,1),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,10,1))
plt.legend(['Data A','Data B'])

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.barh(a,list(range(0,30,1)))
plt.barh(b,list(range(0,30,1)))
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,1),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,10,1))
plt.legend(['Data A','Data B'])

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.violinplot(a,)
plt.violinplot(b,)
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,1),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,10,1))
plt.legend(['Data A','Data B'])

plt.show()

# %%
plt.figure(figsize = (10,6))
plt.pie(a,list(range(0,30,1)))
plt.pie(b,list(range(0,30,1)))
plt.grid()
plt.title('My Graph')
plt.xlabel('x-axis')
plt.xticks(range(0,31,1),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,10,1))
plt.legend(['Data A','Data B'])

plt.show()

# %%
plt.figure(figsize = (20,18))
plt.subplot(1,2,1)
plt.plot(a, color = 'r', ls = '-.', marker = '*',markersize = 10,markeredgecolor = 'g',markerfacecolor = 'deeppink')
plt.grid()
plt.title('My Graph A')
plt.xlabel('x-axis')
plt.xticks(range(0,31,2),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,100,5))
plt.legend(['Data A'])

plt.subplot(1,2,2)
plt.plot(b, color = 'm', ls = ':', marker = 'o',markersize = 10,markeredgecolor = 'blue',markerfacecolor = 'red')
plt.show()
plt.grid()
plt.title('My Graph B')
plt.xlabel('x-axis')
plt.xticks(range(0,31,2),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,100,5))
plt.legend(['DataB'])

# %%
plt.figure(figsize = (20,18))
plt.subplot(1,2,1)
plt.boxplot(a,patch_artist = True,showmeans = True)
plt.grid()
plt.title('My Graph A')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.yticks(range(0,100,5))
plt.legend(['Data A'])


plt.subplot(1,2,2)
plt.plot(b, color = 'm', ls = ':', marker = 'o',markersize = 10,markeredgecolor = 'blue',markerfacecolor = 'red')
plt.grid()
plt.title('My Graph B')
plt.xlabel('x-axis')
plt.xticks(range(0,31,2),list('abcdefghihklmnop'))
plt.ylabel('y-axis')
plt.yticks(range(0,100,5))
plt.legend(['DataB'])
plt.show()

# %%
fig = plt.figure(figsize = (15,6))
ax1 = fig.add_axes([0.01,0.01,0.95,0.95])
ax2 = fig.add_axes([0.3,0.4,0.4,0.4])
ax1.plot(a)
ax2.plot(b)
plt.show()

# %%
fig = plt.figure(figsize = (15,6))
ax1 = fig.add_axes([0.01,0.01,0.95,0.95])
ax2 = fig.add_axes([0.3,0.4,0.4,0.4])
ax1.plot(a)
ax2.plot(y)
plt.show()

# %%
fig = plt.figure(figsize = (15,6))
ax1 = fig.add_axes([0.01,0.01,0.95,0.95])
ax2 = fig.add_axes([0.3,0.4,0.4,0.4])
ax1.plot(a)
ax2.boxplot(y)
plt.show()

# %%
fig = plt.figure(figsize = (15,6))
ax1 = fig.add_axes([0.01,0.01,0.95,0.95])
ax2 = fig.add_axes([0.3,0.4,0.4,0.4])
ax1.scatter(a,b)
ax2.boxplot(y)
plt.show()

# %%
fig = plt.figure(figsize = (15,6))
ax1 = fig.add_axes([0.01,0.01,0.95,0.95])
ax2 = fig.add_axes([0.3,0.4,0.4,0.4])
ax3 = fig.add_axes([0.1,0.9,0.3,0.3])
ax1.scatter(a,b)
ax2.boxplot(y)
plt.show()

# %%
#axes = [x,y,w,h] -- width , height

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.plot(a,color = 'r',ls = '-',marker = '*',markersize = 10,markerfacecolor = 'blue',markeredgecolor = 'green')

plt.grid()
plt.title('My dataa')
plt.xlabel('x-axis')
plt.ylabel('y-label')
plt.xticks(range(0,31,2),list('abcdefghijklmnop'))
plt.yticks(range(0,101,5))
plt.legend(['Data A'])
plt.show()
plt.plot(b,color = 'g',ls = '--',marker = '*',markersize = 10,markerfacecolor = 'yellow',markeredgecolor = 'violet')
plt.grid()
plt.title('My dataa')
plt.xlabel('x-axis')
plt.ylabel('y-label')
plt.xticks(range(0,31,2),list('abcdefghijklmnop'))
plt.yticks(range(0,101,5))
plt.legend(['Data B'])
plt.show()
plt.subplot(1,2,2)

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.boxplot(a)

plt.grid()
plt.title('My dataa')
plt.xlabel('x-axis')
plt.ylabel('y-label')

plt.legend(['Data A'])
plt.show()
plt.boxplot(b)
plt.grid()
plt.title('My dataa')
plt.xlabel('x-axis')
plt.ylabel('y-label')

plt.legend(['Data B'])
plt.show()
plt.subplot(1,2,2)

# %%
fig = plt.figure(figsize=(15,6))
ax1 = fig.add_axes([0.01,0.01,0.95,0.95])
ax2 = fig.add_axes([0.3,0.4,0.4,0.4])
ax2 = fig.add_axes([0.6,0.5,0.2,0.2])
ax1.plot(a)
ax2.plot(b)
plt.show()

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('df1')
df
# Out:
#      Unnamed: 0         A         B         C         D
# 0    2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1    2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2    2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3    2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4    2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ..          ...       ...       ...       ...       ...
# 995  2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 996  2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 997  2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 998  2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 999  2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 5 columns]

# %%
df = pd.read_csv('df1',index_col = 0)
df
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   C       1000 non-null   float64
#  3   D       1000 non-null   float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df.plot()

# %%
df2 = pd.read_csv('df2')

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
print(df2.info())
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes
# None
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.460880   0.352935   0.587008   0.631597
# std     0.340793   0.301272   0.284332   0.258158
# min     0.039762   0.008948   0.103423   0.190008
# 25%     0.212334   0.179302   0.427949   0.457694
# 50%     0.371366   0.240298   0.555036   0.584144
# 75%     0.753558   0.515799   0.873619   0.837267
# max     0.937288   0.997075   0.907307   0.977680

# %%
df2.plot()  
plt.grid()
#legend lagaye hue hai

# %%
#using matplot
plt.plot(df2)

# %% [markdown]
# # Pandas plotting functions
# 1.plot
# 2.plot.area(filled version of plot)
# 3.plot.bar
# 4.plot.barh
# 5.plot.box
# 6.plot.density(smooth curve of histogram)
# 7.plot.hexbin(hexagon of points)
# 8.plot.hist
# 9.plot.kde(kernal density estimator)
# 10.plot.line
# 11.plot.pie(piechart)
# 12.plt.scatter

# %%
df2.plot.area()

# %%
df2.plot.bar()

# %%
df2['a'].plot.bar()

# %%
df2['b'].plot.bar()

# %%
df2[['a','b']].plot.bar()

# %%
df2.plot.barh()

# %%
df2.plot.box()

# %%
df2.boxplot()

# %%
df2.plot.density()

# %%
df2['a'].plot.density()

# %%
df2[['a','b']].plot.density()

# %%
df2.plot.kde()

# %%
df2.plot.line()

# %%
df2.plot.scatter('a','b')

# %%
df2.plot.hexbin('a','b')

# %%
df2.plot.hexbin('a','b',gridsize = 40)

# %%
df3 = pd.DataFrame({'gifts':[20,200,90,89],'names':['rishi','harish','gauri','madhavi']})
df3
# Out:
#    gifts    names
# 0     20    rishi
# 1    200   harish
# 2     90    gauri
# 3     89  madhavi

# %%
df3['gifts'].plot.pie()

# %%
df3['gifts'].plot.pie(autopct = '%d%%',labels = df3['names'])

# %%
#tableu #power bi
